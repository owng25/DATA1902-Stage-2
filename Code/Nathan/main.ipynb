# %%
# !pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 1.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#   Using cached numpy-1.26.0-cp310-cp310-macosx_11_0_arm64.whl (14.0 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.5/502.5 kB 2.4 MB/s eta 0:00:002.5 MB/s eta 0:00:01
# ...
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# ...
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd

# %%
pd.read_csv("../../Data/Merged Data.csv")
# Out:
#            Date  CPI: Food and non-alcoholic beverages  \
# 0    1989-09-01                                   50.0
# 1    1989-12-01                                   50.2
# 2    1990-03-01                                   50.3
# 3    1990-06-01                                   51.7
# 4    1990-09-01                                   51.3
# ..          ...                                    ...
# 131  2022-06-01                                  120.6
# 132  2022-09-01                                  124.5
# 133  2022-12-01                                  125.6
# 134  2023-03-01                                  127.6
# 135  2023-06-01                                  129.7
#
#      CPI: Bread and cereal products  CPI: Bread  CPI: Cakes and biscuits  \
# 0                              46.2        39.8                     49.4
# 1                              47.0        40.8                     50.0
# 2                              48.1        41.6                     51.2
# ...
